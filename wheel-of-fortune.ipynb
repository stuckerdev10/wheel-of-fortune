# %%
import random #importing packages and initializing values for the game
playerScoreList = [0, 0, 0]
playerScoreDict = {1: 0, 2: 0, 3: 0}
spinValues = [100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 0, 'Lose a Turn']
finalscoreList = [0, 0, 0]
vowels = {'a', 'e', 'i', 'o', 'u'}

# %%
def has_numbers(string): #this function helps get rid of words with numbers in them
    return any(char.isdigit() for char in string)

# %%
answerFile = open("words-list.txt", 'r')
answerList = answerFile.read().splitlines()#the following lines clean the list of words with symbols in them
answerList[:] = [row for row in answerList if not '.' in row]
answerList[:] = [row for row in answerList if not '-' in row]
answerList[:] = [row for row in answerList if not "'" in row]
answerList[:] = [row for row in answerList if not '&' in row]
answerList[:] = [row for row in answerList if not '/' in row]
answerList[:] = [row for row in answerList if not has_numbers(row)]


for i in range(0, 150):#gets rid of the first initial words with repeating letters
    answerList.remove(answerList[i])
for i in range(0, len(answerList) - 1):#converts everything to lowercase
    answerList[i] = answerList[i].lower()

# %%
def playersTurn(player):#core gameplay of the first to rounds, takes int of player number to start the round
    global playerScoreDict#bring in score an spin values
    global spinValues
    selectedLetters = []#keeps track of letters already selected
    playing = True 
    while playing == True:#loop to keep the round perpetually going
        print(f"Player {player}'s turn: ")
        print(playingField)
        letterCounter = 0#initializes scoring/answer variables before round
        spinScore = random.choice(spinValues)
        totalAttemptScore = 0
        print(f"Your Rolled: {spinScore}")
        if(spinScore) == 0:#if bankrupt
            print("You went Bankrupt! You lost all your money")
            playerScoreDict[player] = 0
            if player + 1 > 3:#moves to next player, resets to player one if already at 3
                player = 1
            else:
                player = player + 1
        elif spinScore == 'Lose a Turn':#if round lost, moves to next player without losing money
            print("You lost this turn!")
            if player + 1 > 3:
                player = 1
            else:
                player = player + 1
        else:
            print(f"Letters already chosen: {selectedLetters}")
            print('Select a letter or answer the puzzle:')
            attempt = input()#player inputs guess or answers puzzle
            if len(attempt) > 1:#if the player chooses to answer
                answerCounter = 0
                attemptWordList = list(attempt)#breaks attempt into list for iteration
                for count, letter in enumerate(attemptWordList):#count if each letter in the attempt matches the answers letter
                    if attemptWordList[count] == chosenAnswerList[count]:
                        answerCounter += 1
                    else:#if there is a mismatch, move to next player
                        print("Incorrect word")
                        if player + 1 > 3:
                            player = 1
                        else:
                            player = player + 1
                if answerCounter == len(chosenAnswerList):#if each letter matches the answer
                    print("Congratulations! You chose the correct word")
                    finalscoreList[player - 1] = playerScoreDict[player]#players score is saved to the final score
                    break
            else:#if they are guessing just a letter
                letterCounter = 0#tracks how many times a letter appears
    
                selecting = True

                while selecting == True:#while loop to let player continue to guess in case of error

                    if attempt in selectedLetters:#if the letter was already chosen, continue to next player
                        print("Letter already chosen")
                        break
                    else:
                        if attempt in vowels:#if letter is in vowels set
                            print('You bought a vowel for $250')
                            if playerScoreDict[player] < 250:#if player can't afford a vowel, cancel and move to next player
                                print("Sorry, you don't have enough money to buy a vowel")
                                if player + 1 > 3:
                                    player = 1
                                else:
                                    player = player + 1
                                break
                            else:#if they can afford, add to selectedLetters and subtrack 250 from their score
                                selectedLetters.append(attempt)
                                playerScoreDict[player] = playerScoreDict[player] - 250
                            if attempt in chosenAnswerList:#if letter exists in the answer
                                print('Correct Choice!')
                            else:
                                print("Incorrect choice")#if its the wrong letter, move on to next player
                                if player + 1 > 3:
                                    player = 1
                                else:
                                    player = player + 1
                                break
                            for count, letter in enumerate(chosenAnswerList):#keeps track of how many times letter appears,
                                if chosenAnswerList[count] == attempt:
                                    letterCounter += 1
                                    playingField[count] = attempt#replaces underscores on playing field with the letter
                            totalAttemptScore = letterCounter * spinScore#calculates total score of attempt
                            playerScoreDict[player] = playerScoreDict[player] + totalAttemptScore
                            print(f"This letter appeared {letterCounter} times for a score of {totalAttemptScore}")
                            print(f"Your new score is {playerScoreDict[player]}")
                            print(playingField)
                        else:#if the guess is a constonant
                            print('this is a constonant')
                            if attempt in chosenAnswerList:#if correct move on
                                selectedLetters.append(attempt)
                                print('Correct Choice!')
                            else:
                                selectedLetters.append(attempt)#if incorrect move to next player
                                print('Incorrect choice')
                                if player + 1 > 3:
                                    player = 1
                                else:
                                    player = player + 1
                                break
                            for count, letter in enumerate(chosenAnswerList):#same scoring scheme as before
                                if chosenAnswerList[count] == attempt:
                                    letterCounter += 1
                                    playingField[count] = attempt
                            totalAttemptScore = letterCounter * spinScore
                            playerScoreDict[player] = playerScoreDict[player] + totalAttemptScore
                            print(f"This letter appeared {letterCounter} times for a score of {totalAttemptScore}")
                            print(playingField)
                    print(f"Scores: {playerScoreDict}")

# %%
def finalRound(player):#final round of the game, player with max score plays
    global vowels
    print(f"Congratulations player {player}! You have made it to the final round")
    print("This next round is worth $1,000,000.")
    print("Here is the word: ")
    chosenAnswer = random.choice(answerList)#choose new word
    chosenAnswerList = list(chosenAnswer)
    playingField = []
    for letter in chosenAnswerList:
        playingField.append('_')
    print(playingField)#display word to player
    print("Here is the word after the default clues (r s t l n e)")
    defaultClues = ['r', 's', 't', 'l', 'n' 'e']
    for count, letter in enumerate(chosenAnswerList):#this loop checks each letter in chosenAnswerList against the default clues
        for letter in defaultClues:
            if letter == chosenAnswerList[count]:
                playingField[count] = letter#replaces the underscore with the letter if they match
                break
    print(playingField)
    guessSelections = []
    for i in range(1, 4):#player chooses 3 constonants, which gets put in guessSelections List
        print(f"Select constonant {i}")
        attempt = input()
        if len(attempt) > 1 or attempt in vowels:#checks to see if constonant in proper format
            while len(attempt) > 1 or attempt in vowels:
                print("invalid format, please enter again")
                attempt = input()
        guessSelections.append(attempt)
    print("Now choose a vowel: ")
    attempt = input()#user must choose a vowel
    if attempt not in vowels:#checks to see if letter is actually a vowel
        while attempt not in vowels:
            print("Not a vowel, please try again: ")
            attempt = input()
    guessSelections.append(attempt)
    print(f"Here are your selections: {guessSelections}")
    print("Here is the new playing field: ")
    for count, letter in enumerate(chosenAnswerList):#runs through letters against chosenAnswerList
        for letter in guessSelections:
            if letter == chosenAnswerList[count]:
                playingField[count] = letter
                break
    print(playingField)
    print("For $1,000,000 dollars, what is the word?")
    attempt = input()#player inputs guess
    answerCounter = 0
    attemptWordList = list(attempt)
    for count, letter in enumerate(attemptWordList):#runs through same word guessing progress as previous rounds
        if attemptWordList[count] == chosenAnswerList[count]:
            answerCounter += 1
        else:
            print("Incorrect word")
            break
    if answerCounter == len(chosenAnswerList):
        print("Congratulations! You chose the correct word")

# %%
print("-------------------------------------")#begin first round
print("      Wheel of Fortune: Round 1      ")
print("-------------------------------------")
print("Here is your word: ")
chosenAnswer = random.choice(answerList)#choose random word, the break into list
chosenAnswerList = list(chosenAnswer)
playingField = []#set up visable playing field mirroring the chosenAnswerList, filled with  underscores instead of letters
for letter in chosenAnswerList:
    playingField.append('_')
print(playingField)
playersTurn(1)#Game starts with player 1
print("Here are the new standings: ")#displays new standings
print(f"Player 1: {finalscoreList[0]}\n Player 2: {finalscoreList[1]}\n Player 3: {finalscoreList[2]}")

playerScoreDict = {1: 0, 2: 0, 3: 0}

print("-------------------------------------")#begin round 2
print("      Wheel of Fortune: Round 2      ")
print("-------------------------------------")
print("Here is your new word: ")#same answer choosing process as before
chosenAnswer = random.choice(answerList)
chosenAnswerList = list(chosenAnswer)
playingField = []
for letter in chosenAnswerList:
    playingField.append('_')
print(playingField)
lastPlace = min(finalscoreList)#starts with player who is at the lowest value
lastPlaceIndex = finalscoreList.index(lastPlace) + 1
playersTurn(lastPlaceIndex)

firstPlace = max(finalscoreList)#finds the player with the highest final score for the final round
firstPlaceIndex = finalscoreList.index(firstPlace) + 1

print("-------------------------------------")
print("      Wheel of Fortune: Final Round      ")
print("-------------------------------------")
finalRound(firstPlaceIndex)#begin final round
# Out:
# -------------------------------------
#       Wheel of Fortune: Round 1
# -------------------------------------
# Here is your word:
# ['_', '_', '_', '_', '_', '_', '_']
# Player 1's turn:
# ['_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 2's turn:
# ['_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 200
# Letters already chosen: []
# Select a letter or answer the puzzle:
# r
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 800
# Letters already chosen: ['r']
# Select a letter or answer the puzzle:
# s
# this is a constonant
# Incorrect choice
# Player 1's turn:
# ['_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 2's turn:
# ['_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 900
# Letters already chosen: ['r', 's']
# Select a letter or answer the puzzle:
# t
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 900
# ['_', '_', '_', '_', '_', '_', 't']
# Scores: {1: 0, 2: 900, 3: 0}
# Letter already chosen
# Player 2's turn:
# ['_', '_', '_', '_', '_', '_', 't']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't']
# Select a letter or answer the puzzle:
# l
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['_', '_', '_', '_', '_', '_', 't']
# Your Rolled: 800
# Letters already chosen: ['r', 's', 't', 'l']
# Select a letter or answer the puzzle:
# n
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 800
# ['_', '_', '_', '_', '_', 'n', 't']
# Scores: {1: 0, 2: 900, 3: 800}
# Letter already chosen
# Player 3's turn:
# ['_', '_', '_', '_', '_', 'n', 't']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n']
# Select a letter or answer the puzzle:
# e
# You bought a vowel for $250
# Correct Choice!
# This letter appeared 1 times for a score of 850
# Your new score is 1400
# ['_', 'e', '_', '_', '_', 'n', 't']
# Scores: {1: 0, 2: 900, 3: 1400}
# Letter already chosen
# Player 3's turn:
# ['_', 'e', '_', '_', '_', 'n', 't']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e']
# Select a letter or answer the puzzle:
# z
# this is a constonant
# Incorrect choice
# Player 1's turn:
# ['_', 'e', '_', '_', '_', 'n', 't']
# Your Rolled: 200
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z']
# Select a letter or answer the puzzle:
# x
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', 'e', '_', '_', '_', 'n', 't']
# Your Rolled: 550
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x']
# Select a letter or answer the puzzle:
# c
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 550
# ['_', 'e', 'c', '_', '_', 'n', 't']
# Scores: {1: 0, 2: 1450, 3: 1400}
# Letter already chosen
# Player 2's turn:
# ['_', 'e', 'c', '_', '_', 'n', 't']
# Your Rolled: 650
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c']
# Select a letter or answer the puzzle:
# v
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['_', 'e', 'c', '_', '_', 'n', 't']
# Your Rolled: 150
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v']
# Select a letter or answer the puzzle:
# b
# this is a constonant
# Incorrect choice
# Player 1's turn:
# ['_', 'e', 'c', '_', '_', 'n', 't']
# Your Rolled: 650
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b']
# Select a letter or answer the puzzle:
# n
# Letter already chosen
# Player 1's turn:
# ['_', 'e', 'c', '_', '_', 'n', 't']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b']
# Select a letter or answer the puzzle:
# m
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 850
# ['m', 'e', 'c', '_', '_', 'n', 't']
# Scores: {1: 850, 2: 1450, 3: 1400}
# Letter already chosen
# Player 1's turn:
# ['m', 'e', 'c', '_', '_', 'n', 't']
# Your Rolled: 400
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm']
# Select a letter or answer the puzzle:
# a
# You bought a vowel for $250
# Correct Choice!
# This letter appeared 1 times for a score of 400
# Your new score is 1000
# ['m', 'e', 'c', '_', 'a', 'n', 't']
# Scores: {1: 1000, 2: 1450, 3: 1400}
# Letter already chosen
# Player 1's turn:
# ['m', 'e', 'c', '_', 'a', 'n', 't']
# Your Rolled: 150
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a']
# Select a letter or answer the puzzle:
# h
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 150
# ['m', 'e', 'c', 'h', 'a', 'n', 't']
# Scores: {1: 1150, 2: 1450, 3: 1400}
# Letter already chosen
# Player 1's turn:
# ['m', 'e', 'c', 'h', 'a', 'n', 't']
# Your Rolled: 450
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'h']
# Select a letter or answer the puzzle:
# mechant
# Congratulations! You chose the correct word
# Here are the new standings:
# Player 1: 1150
#  Player 2: 0
#  Player 3: 0
# -------------------------------------
#       Wheel of Fortune: Round 2
# -------------------------------------
# Here is your new word:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Player 2's turn:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 3's turn:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 1's turn:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Your Rolled: 800
# Letters already chosen: []
# Select a letter or answer the puzzle:
# r
# this is a constonant
# Correct Choice!
# This letter appeared 2 times for a score of 1600
# ['_', '_', 'r', 'r', '_', '_', '_', '_', '_']
# Scores: {1: 1600, 2: 0, 3: 0}
# Letter already chosen
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', '_', '_']
# Your Rolled: 500
# Letters already chosen: ['r']
# Select a letter or answer the puzzle:
# s
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', '_', '_']
# Your Rolled: 850
# Letters already chosen: ['r', 's']
# Select a letter or answer the puzzle:
# t
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 850
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Scores: {1: 1600, 2: 850, 3: 0}
# Letter already chosen
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 450
# Letters already chosen: ['r', 's', 't']
# Select a letter or answer the puzzle:
# l
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 250
# Letters already chosen: ['r', 's', 't', 'l']
# Select a letter or answer the puzzle:
# n
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 650
# Letters already chosen: ['r', 's', 't', 'l', 'n']
# Select a letter or answer the puzzle:
# e
# You bought a vowel for $250
# Incorrect choice
# Player 3's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 900
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e']
# Select a letter or answer the puzzle:
# z
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 500
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z']
# Select a letter or answer the puzzle:
# x
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x']
# Select a letter or answer the puzzle:
# c
# this is a constonant
# Incorrect choice
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 700
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c']
# Select a letter or answer the puzzle:
# v
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 3's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 800
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v']
# Select a letter or answer the puzzle:
# b
# this is a constonant
# Incorrect choice
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 400
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b']
# Select a letter or answer the puzzle:
# n
# Letter already chosen
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 600
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b']
# Select a letter or answer the puzzle:
# m
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 750
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm']
# Select a letter or answer the puzzle:
# a
# You bought a vowel for $250
# Sorry, you don't have enough money to buy a vowel
# Player 3's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 150
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm']
# Select a letter or answer the puzzle:
# a
# You bought a vowel for $250
# Sorry, you don't have enough money to buy a vowel
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 650
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm']
# Select a letter or answer the puzzle:
# a
# You bought a vowel for $250
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 600
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a']
# Select a letter or answer the puzzle:
# s
# Letter already chosen
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', '_', '_', 't', '_']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a']
# Select a letter or answer the puzzle:
# d
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 850
# ['_', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Scores: {1: 1350, 2: 850, 3: 0}
# Letter already chosen
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 650
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd']
# Select a letter or answer the puzzle:
# f
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['_', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: Lose a Turn
# You lost this turn!
# Player 1's turn:
# ['_', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 900
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f']
# Select a letter or answer the puzzle:
# g
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['_', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 750
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g']
# Select a letter or answer the puzzle:
# h
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 750
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Scores: {1: 1350, 2: 1600, 3: 0}
# Letter already chosen
# Player 2's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 750
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h']
# Select a letter or answer the puzzle:
# j
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 1's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j']
# Select a letter or answer the puzzle:
# k
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 700
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k']
# Select a letter or answer the puzzle:
# l
# Letter already chosen
# Player 2's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 500
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k']
# Select a letter or answer the puzzle:
# q
# this is a constonant
# Incorrect choice
# Player 3's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 450
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q']
# Select a letter or answer the puzzle:
# w
# this is a constonant
# Incorrect choice
# Player 1's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 200
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w']
# Select a letter or answer the puzzle:
# r
# Letter already chosen
# Player 1's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 150
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w']
# Select a letter or answer the puzzle:
# t
# Letter already chosen
# Player 1's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', '_']
# Your Rolled: 150
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w']
# Select a letter or answer the puzzle:
# y
# this is a constonant
# Correct Choice!
# This letter appeared 1 times for a score of 150
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', 'y']
# Scores: {1: 1500, 2: 1600, 3: 0}
# Letter already chosen
# Player 1's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 400
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y']
# Select a letter or answer the puzzle:
# u
# You bought a vowel for $250
# Incorrect choice
# Player 2's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 0
# You went Bankrupt! You lost all your money
# Player 3's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 550
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u']
# Select a letter or answer the puzzle:
# i
# You bought a vowel for $250
# Sorry, you don't have enough money to buy a vowel
# Player 1's turn:
# ['h', '_', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 250
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u']
# Select a letter or answer the puzzle:
# o
# You bought a vowel for $250
# Correct Choice!
# This letter appeared 1 times for a score of 250
# Your new score is 1250
# ['h', 'o', 'r', 'r', '_', 'd', '_', 't', 'y']
# Scores: {1: 1250, 2: 0, 3: 0}
# Letter already chosen
# Player 1's turn:
# ['h', 'o', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 300
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u', 'o']
# Select a letter or answer the puzzle:
# p
# this is a constonant
# Incorrect choice
# Player 2's turn:
# ['h', 'o', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 250
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u', 'o', 'p']
# Select a letter or answer the puzzle:
# i
# You bought a vowel for $250
# Sorry, you don't have enough money to buy a vowel
# Player 3's turn:
# ['h', 'o', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 100
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u', 'o', 'p']
# Select a letter or answer the puzzle:
# i
# You bought a vowel for $250
# Sorry, you don't have enough money to buy a vowel
# Player 1's turn:
# ['h', 'o', 'r', 'r', '_', 'd', '_', 't', 'y']
# Your Rolled: 350
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u', 'o', 'p']
# Select a letter or answer the puzzle:
# i
# You bought a vowel for $250
# Correct Choice!
# This letter appeared 2 times for a score of 700
# Your new score is 1700
# ['h', 'o', 'r', 'r', 'i', 'd', 'i', 't', 'y']
# Scores: {1: 1700, 2: 0, 3: 0}
# Letter already chosen
# Player 1's turn:
# ['h', 'o', 'r', 'r', 'i', 'd', 'i', 't', 'y']
# Your Rolled: 850
# Letters already chosen: ['r', 's', 't', 'l', 'n', 'e', 'z', 'x', 'c', 'v', 'b', 'm', 'a', 'd', 'f', 'g', 'h', 'j', 'k', 'q', 'w', 'y', 'u', 'o', 'p', 'i']
# Select a letter or answer the puzzle:
# horridity
# Congratulations! You chose the correct word
# -------------------------------------
#       Wheel of Fortune: Final Round
# -------------------------------------
# Congratulations player 1! You have made it to the final round
# This next round is worth $1,000,000.
# Here is the word:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_']
# Here is the word after the default clues (r s t l n e)
# ['r', '_', '_', '_', 'r', 't', 's', '_', '_']
# Select constonant 1
# h
# Select constonant 2
# w
# Select constonant 3
# m
# Now choose a vowel:
# o
# Here are your selections: ['h', 'w', 'm', 'o']
# Here is the new playing field:
# ['r', 'o', '_', '_', 'r', 't', 's', 'o', '_']
# For $1,000,000 dollars, what is the word?
# rorrrtsor
# Incorrect word

# %%
testList = [2, 4, 6]
print(testList.index(min(testList)))
print(testList)
# Out:
# 0
# [2, 4, 6]

# %%
def playersTurn(player):#core gameplay of the first to rounds, takes int of player number to start the round
    global playerScoreDict#bring in score an spin values
    global spinValues
    selectedLetters = []#keeps track of letters already selected
    playing = True 
    while playing == True:#loop to keep the round perpetually going
        print(f"Player {player}'s turn: ")
        print(playingField)
        letterCounter = 0#initializes scoring/answer variables before round
        spinScore = random.choice(spinValues)
        totalAttemptScore = 0
        print(f"Your Rolled: {spinScore}")
        if(spinScore) == 0:#if bankrupt
            print("You went Bankrupt! You lost all your money")
            playerScoreDict[player] = 0
            if player + 1 > 3:#moves to next player, resets to player one if already at 3
                player = 1
            else:
                player = player + 1
        elif spinScore == 'Lose a Turn':#if round lost, moves to next player without losing money
            print("You lost this turn!")
            if player + 1 > 3:
                player = 1
            else:
                player = player + 1
        else:
            print(f"Letters already chosen: {selectedLetters}")
            print('Select a letter or answer the puzzle:')
            attempt = input()#player inputs guess or answers puzzle
            if len(attempt) > 1:#if the player chooses to answer
                answerCounter = 0
                attemptWordList = list(attempt)#breaks attempt into list for iteration
                for count, letter in enumerate(attemptWordList):#count if each letter in the attempt matches the answers letter
                    if attemptWordList[count] == chosenAnswerList[count]:
                        answerCounter += 1
                    else:#if there is a mismatch, move to next player
                        print("Incorrect word")
                        if player + 1 > 3:
                            player = 1
                        else:
                            player = player + 1
                if answerCounter == len(chosenAnswerList):#if each letter matches the answer
                    print("Congratulations! You chose the correct word")
                    finalscoreList[player - 1] = playerScoreDict[player]#players score is saved to the final score
                    break
            else:#if they are guessing just a letter
                letterCounter = 0#tracks how many times a letter appears
    
                selecting = True

                while selecting == True:#while loop to let player continue to guess in case of error

                    if attempt in selectedLetters:#if the letter was already chosen, continue to next player
                        print("Letter already chosen")
                        break
                    else:
                        if attempt in vowels:#if letter is in vowels set
                            print('You bought a vowel for $250')
                            if playerScoreDict[player] < 250:#if player can't afford a vowel, cancel and move to next player
                                print("Sorry, you don't have enough money to buy a vowel")
                                if player + 1 > 3:
                                    player = 1
                                else:
                                    player = player + 1
                                break
                            else:#if they can afford, add to selectedLetters and subtrack 250 from their score
                                selectedLetters.append(attempt)
                                playerScoreDict[player] = playerScoreDict[player] - 250
                            if attempt in chosenAnswerList:#if letter exists in the answer
                                print('Correct Choice!')
                            else:
                                print("Incorrect choice")#if its the wrong letter, move on to next player
                                if player + 1 > 3:
                                    player = 1
                                else:
                                    player = player + 1
                                break
                            for count, letter in enumerate(chosenAnswerList):#keeps track of how many times letter appears,
                                if chosenAnswerList[count] == attempt:
                                    letterCounter += 1
                                    playingField[count] = attempt#replaces underscores on playing field with the letter
                            totalAttemptScore = letterCounter * spinScore#calculates total score of attempt
                            playerScoreDict[player] = playerScoreDict[player] + totalAttemptScore
                            print(f"This letter appeared {letterCounter} times for a score of {totalAttemptScore}")
                            print(f"Your new score is {playerScoreDict[player]}")
                            print(playingField)
                        else:#if the guess is a constonant
                            print('this is a constonant')
                            if attempt in chosenAnswerList:#if correct move on
                                selectedLetters.append(attempt)
                                print('Correct Choice!')
                            else:
                                selectedLetters.append(attempt)#if incorrect move to next player
                                print('Incorrect choice')
                                if player + 1 > 3:
                                    player = 1
                                else:
                                    player = player + 1
                                break
                            for count, letter in enumerate(chosenAnswerList):#same scoring scheme as before
                                if chosenAnswerList[count] == attempt:
                                    letterCounter += 1
                                    playingField[count] = attempt
                            totalAttemptScore = letterCounter * spinScore
                            playerScoreDict[player] = playerScoreDict[player] + totalAttemptScore
                            print(f"This letter appeared {letterCounter} times for a score of {totalAttemptScore}")
                            print(playingField)
                    print(f"Scores: {playerScoreDict}")

# %%
def attemptWord(player, word, playing):
    global chosenAnswerList
    answerCounter = 0
    attemptWordList = list(word)
    for count, letter in enumerate(attemptWordList):
        if attemptWordList[count] == chosenAnswerList[count]:
            answerCounter += 1
        else:
            print("Incorrect word")
            break
    if answerCounter == len(chosenAnswerList):
        print("Congratulations! You chose the correct word")

# %%
def attemptChar(player, attempt, spin):
    global chosenAnswerList
    global playerScoreDict
    global vowels
    global selectedLetters
    
    letterCounter = 0
    
    selecting = True
    
    while selecting == True:
       
        if attempt in selectedLetters:
            print("Letter already chosen")
            break
        else:
            print(f"Chosen letters: {selectedLetters}")
            if attempt in vowels:
                print('You bought a vowel for $250')
                if playerScoreDict[player] < 250:
                    print("Sorry, you don't have enough money to buy a vowel")
                    chosenAnswerList.pop()
                    break
                else:
                    selectedLetters.append(attempt)
                    playerScoreDict[player] = playerScoreDict[player] - 250
                if attempt in chosenAnswerList:
                    print('Correct Choice!')
                else:
                    print("Incorrect choice")
                    break
                for count, letter in enumerate(chosenAnswerList):
                    if chosenAnswerList[count] == attempt:
                        letterCounter += 1
                        playingField[count] = attempt
                totalAttemptScore = letterCounter * spin
                playerScoreDict[player] = playerScoreDict[player] + totalAttemptScore
                print(f"This letter appeared {letterCounter} times for a score of {totalAttemptScore}")
                print(f"Your new score is {playerScoreDict[player]}")
                print(playingField)
            else:
                print('this is a constonant')
                if attempt in chosenAnswerList:
                    print('Correct Choice!')
                else:
                    print('Incorrect choice')
                    break
                for count, letter in enumerate(chosenAnswerList):
                    if chosenAnswerList[count] == attempt:
                        letterCounter += 1
                        playingField[count] = attempt
                totalAttemptScore = letterCounter * spinScore
                playerScoreDict[player] = playerScoreDict[player] + totalAttemptScore
                print(f"This letter appeared {letterCounter} times for a score of {totalAttemptScore}")
                print(playingField)

# %%
def finalRound(player):#final round of the game, player with max score plays
    global vowels
    print(f"Congratulations player {player}! You have made it to the final round")
    print("This next round is worth $1,000,000.")
    print("Here is the word: ")
    chosenAnswer = random.choice(answerList)#choose new word
    chosenAnswerList = list(chosenAnswer)
    playingField = []
    for letter in chosenAnswerList:
        playingField.append('_')
    print(playingField)#display word to player
    print("Here is the word after the default clues (r s t l n e)")
    defaultClues = ['r', 's', 't', 'l', 'n' 'e']
    for count, letter in enumerate(chosenAnswerList):#this loop checks each letter in chosenAnswerList against the default clues
        for letter in defaultClues:
            if letter == chosenAnswerList[count]:
                playingField[count] = letter#replaces the underscore with the letter if they match
                break
    print(playingField)
    guessSelections = []
    for i in range(1, 4):#player chooses 3 constonants, which gets put in guessSelections List
        print(f"Select constonant {i}")
        attempt = input()
        if len(attempt) > 1 or attempt in vowels:#checks to see if constonant in proper format
            while len(attempt) > 1 or attempt in vowels:
                print("invalid format, please enter again")
                attempt = input()
        guessSelections.append(attempt)
    print("Now choose a vowel: ")
    attempt = input()#user must choose a vowel
    if attempt not in vowels:#checks to see if letter is actually a vowel
        while attempt not in vowels:
            print("Not a vowel, please try again: ")
            attempt = input()
    guessSelections.append(attempt)
    print(f"Here are your selections: {guessSelections}")
    print("Here is the new playing field: ")
    for count, letter in enumerate(chosenAnswerList):#runs through letters against chosenAnswerList
        for letter in guessSelections:
            if letter == chosenAnswerList[count]:
                playingField[count] = letter
                break
    print(playingField)
    print("For $1,000,000 dollars, what is the word?")
    attempt = input()#player inputs guess
    answerCounter = 0
    attemptWordList = list(attempt)
    for count, letter in enumerate(attemptWordList):#runs through same word guessing progress as previous rounds
        if attemptWordList[count] == chosenAnswerList[count]:
            answerCounter += 1
        else:
            print("Incorrect word")
            break
    if answerCounter == len(chosenAnswerList):
        print("Congratulations! You chose the correct word")
